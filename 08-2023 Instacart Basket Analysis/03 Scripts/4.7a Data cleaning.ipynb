# %%
# Import librabries

import pandas as pd
import numpy as np
import os

# %%
# Import dataframes

path = r'C:\Users\bruna\Career Foundry\08-2023 Instacart Basket Analysis'

# %%
df_ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
# Visualising df_ords_prods_merged

df_ords_prods_merged.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  time_of_order  \
# 0    2539329        1             1                   2              8
# 1    2398795        1             2                   3              7
# 2     473747        1             3                   3             12
# 3    2254736        1             4                   4              7
# 4     431534        1             5                   4             15
# 5    3367565        1             6                   2              7
# 6     550135        1             7                   1              9
# 7    3108588        1             8                   1             14
# 8    2295261        1             9                   1             16
# 9    2550362        1            10                   4              8
# 10   2968173       15            15                   1              9
# 11   1870022       15            17                   2             16
# ...

# %%
df_ords_prods_merged.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.240486e+07  3.240486e+07  3.240486e+07        3.240486e+07
# mean   1.710745e+06  1.029372e+05  1.714230e+01        2.738867e+00
# std    9.872988e+05  5.946610e+04  1.753532e+01        2.090077e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.559470e+05  5.142200e+04  5.000000e+00        1.000000e+00
# 50%    1.711049e+06  1.026160e+05  1.100000e+01        3.000000e+00
# 75%    2.565499e+06  1.543890e+05  2.400000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01        6.000000e+00
#
#        time_of_order  days_since_prior_order    product_id  add_to_cart_order  \
# count   3.240486e+07            3.032876e+07  3.240486e+07       3.240486e+07
# mean    1.342515e+01            1.110408e+01  2.559866e+04       8.352547e+00
# std     4.246380e+00            8.779064e+00  1.408400e+04       7.127071e+00
# ...

# %%
# Max price 99999. Find out the top prices in data
top_prices = df_ords_prods_merged['prices'].nlargest(10000).unique()

# %%
print(top_prices)
# Out:
# [9.9999e+04 1.4900e+04 2.5000e+01]

# %%
# Replace 99999 and 14900 with median (7.4)

replacement_prices = {99999: np.nan, 14900: np.nan}
df_ords_prods_merged['prices'] = df_ords_prods_merged['prices'].replace(replacement_prices)

# %%
df_ords_prods_merged.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.240486e+07  3.240486e+07  3.240486e+07        3.240486e+07
# mean   1.710745e+06  1.029372e+05  1.714230e+01        2.738867e+00
# std    9.872988e+05  5.946610e+04  1.753532e+01        2.090077e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.559470e+05  5.142200e+04  5.000000e+00        1.000000e+00
# 50%    1.711049e+06  1.026160e+05  1.100000e+01        3.000000e+00
# 75%    2.565499e+06  1.543890e+05  2.400000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01        6.000000e+00
#
#        time_of_order  days_since_prior_order    product_id  add_to_cart_order  \
# count   3.240486e+07            3.032876e+07  3.240486e+07       3.240486e+07
# mean    1.342515e+01            1.110408e+01  2.559866e+04       8.352547e+00
# std     4.246380e+00            8.779064e+00  1.408400e+04       7.127071e+00
# ...

# %%
# Exporting 'orders_products_merged.pkl'

df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))
